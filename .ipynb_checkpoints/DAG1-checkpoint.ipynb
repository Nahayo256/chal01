# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({'key1' : ['a', 'a', 'b', 'b', 'a'],'key2' : ['one', 'two', 'one', 'two', 'one'],'data1' : np.random.randn(5),'data2' : np.random.randn(5)})

# %%
df
# Out:
#   key1 key2     data1     data2
# 0    a  one  0.972499  0.901036
# 1    a  two  1.100574  0.342033
# 2    b  one  1.242830  0.719637
# 3    b  two -0.615016 -1.088308
# 4    a  one  0.138021  0.084650

# %%
grouped = df['data1'].groupby(df['key1'])

# %%
grouped

# %%
grouped.mean()
# Out:
# key1
# a    0.737031
# b    0.313907
# Name: data1, dtype: float64

# %%
means = df['data1'].groupby([df['key1'], df['key2']]).mean()
means
# Out:
# key1  key2
# a     one     0.555260
#       two     1.100574
# b     one     1.242830
#       two    -0.615016
# Name: data1, dtype: float64

# %%
means.unstack()
# Out:
# key2      one       two
# key1
# a     0.55526  1.100574
# b     1.24283 -0.615016

# %%
states = np.array(['Ohio', 'California', 'California', 'Ohio', 'Ohio'])

# %%
years = np.array([2005, 2005, 2006, 2005, 2006])

# %%
df['data1'].groupby([states, years]).mean()
# Out:
# California  2005    1.100574
#             2006    1.242830
# Ohio        2005    0.178741
#             2006    0.138021
# Name: data1, dtype: float64

# %%
df.groupby('key1').mean()
# Out:
#          data1     data2
# key1
# a     0.737031  0.442573
# b     0.313907 -0.184336

# %%
df.groupby(['key1', 'key2']).mean()
# Out:
#               data1     data2
# key1 key2
# a    one   0.555260  0.492843
#      two   1.100574  0.342033
# b    one   1.242830  0.719637
#      two  -0.615016 -1.088308

# %%
df.groupby(['key1', 'key2']).size()
# Out:
# key1  key2
# a     one     2
#       two     1
# b     one     1
#       two     1
# dtype: int64

# %%
for name, group in df.groupby('key1'):
    print(name)
    print (group)
# Out:
# a
#   key1 key2     data1     data2
# 0    a  one  0.972499  0.901036
# 1    a  two  1.100574  0.342033
# 4    a  one  0.138021  0.084650
# b
#   key1 key2     data1     data2
# 2    b  one  1.242830  0.719637
# 3    b  two -0.615016 -1.088308

# %%
for (k1, k2), group in df.groupby(['key1', 'key2']):
    print(k1, k2)
    print(group)
# Out:
# a one
#   key1 key2     data1     data2
# 0    a  one  0.972499  0.901036
# 4    a  one  0.138021  0.084650
# a two
#   key1 key2     data1     data2
# 1    a  two  1.100574  0.342033
# b one
#   key1 key2    data1     data2
# 2    b  one  1.24283  0.719637
# b two
#   key1 key2     data1     data2
# 3    b  two -0.615016 -1.088308

# %%
pieces = dict(list(df.groupby('key1')))

# %%
pieces['b']
# Out:
#   key1 key2     data1     data2
# 2    b  one  1.242830  0.719637
# 3    b  two -0.615016 -1.088308

# %%
df.dtypes
# Out:
# key1      object
# key2      object
# data1    float64
# data2    float64
# dtype: object

# %%
grouped = df.groupby(df.dtypes, axis=1)

# %%
dict(list(grouped))
# Out:
# {dtype('float64'):       data1     data2
#  0  0.972499  0.901036
#  1  1.100574  0.342033
#  2  1.242830  0.719637
#  3 -0.615016 -1.088308
#  4  0.138021  0.084650, dtype('O'):   key1 key2
#  0    a  one
#  1    a  two
#  2    b  one
#  3    b  two
#  4    a  one}

# %%
df.groupby(['key1', 'key2'])[['data2']].mean()
# Out:
#               data2
# key1 key2
# a    one   0.492843
#      two   0.342033
# b    one   0.719637
#      two  -1.088308

# %%
s_grouped = df.groupby(['key1', 'key2'])['data2']

# %%
s_grouped

# %%
s_grouped.mean()
# Out:
# key1  key2
# a     one     0.492843
#       two     0.342033
# b     one     0.719637
#       two    -1.088308
# Name: data2, dtype: float64

# %%
import numpy as np
import pandas as pd
people = pd.DataFrame(np.random.randn(5, 5), columns=['a', 'b', 'c', 'd', 'e'], index=['Joe', 'Steve', 'Wes', 'Jim', 'Travis'])

# %%
people.loc[2:3, ['b', 'c']] = np.nan

# %%
people
# Out:
#                a         b         c         d         e
# Joe    -0.868921 -1.432694 -1.079060  0.578746  0.326481
# Steve  -1.207845  0.257903 -1.116961  1.187443 -0.788250
# Wes    -0.467899       NaN       NaN  0.973890  0.892167
# Jim    -2.404699  0.296072 -0.960654  0.211602 -0.007448
# Travis  1.400957  0.178220 -0.469583  0.146292 -1.871356

# %%
mapping = {'a': 'red', 'b': 'red', 'c': 'blue','d': 'blue', 'e': 'red', 'f' : 'orange'}

# %%
by_column = people.groupby(mapping, axis=1)

# %%
by_column.sum()
# Out:
#             blue       red
# Joe    -0.500314 -1.975134
# Steve   0.070482 -1.738192
# Wes     0.973890  0.424268
# Jim    -0.749052 -2.116075
# Travis -0.323290 -0.292178

# %%
map_series = mapping

# %%
map_series
# Out:
# {'a': 'red', 'b': 'red', 'c': 'blue', 'd': 'blue', 'e': 'red', 'f': 'orange'}

# %%
people.groupby(map_series, axis=1).count()
# Out:
#         blue  red
# Joe        2    3
# Steve      2    3
# Wes        1    2
# Jim        2    3
# Travis     2    3

# %%
people.groupby(len).sum()
# Out:
#           a         b         c         d         e
# 3 -3.741520 -1.136622 -2.039714  1.764238  1.211200
# 5 -1.207845  0.257903 -1.116961  1.187443 -0.788250
# 6  1.400957  0.178220 -0.469583  0.146292 -1.871356

# %%
key_list = ['one', 'one', 'one', 'two', 'two']

# %%
people.groupby([len, key_list]).min()
# Out:
#               a         b         c         d         e
# 3 one -0.868921 -1.432694 -1.079060  0.578746  0.326481
#   two -2.404699  0.296072 -0.960654  0.211602 -0.007448
# 5 one -1.207845  0.257903 -1.116961  1.187443 -0.788250
# 6 two  1.400957  0.178220 -0.469583  0.146292 -1.871356

# %%
columns = pd.MultiIndex.from_arrays([['US', 'US', 'US', 'JP', 'JP'],
[1, 3, 5, 1, 3]], names=['cty', 'tenor'])

# %%
hier_df = pd.DataFrame(np.random.randn(4, 5), columns=columns)

# %%
hier_df
# Out:
# cty          US                            JP
# tenor         1         3         5         1         3
# 0     -1.320446  1.095438 -0.736675  0.846911 -0.428439
# 1      1.522000 -0.928911 -0.387801 -0.231727 -2.359638
# 2      0.222283  1.238726 -0.283214  0.777383 -0.610446
# 3     -0.467678 -1.210613 -2.563319  0.819398  0.157675

# %%
hier_df.groupby(level='cty', axis=1).count()
# Out:
# cty  JP  US
# 0     2   3
# 1     2   3
# 2     2   3
# 3     2   3

# %%
df
# Out:
#   key1 key2     data1     data2
# 0    a  one  0.972499  0.901036
# 1    a  two  1.100574  0.342033
# 2    b  one  1.242830  0.719637
# 3    b  two -0.615016 -1.088308
# 4    a  one  0.138021  0.084650

# %%
grouped = df.groupby('key1')

# %%
grouped['data1'].quantile(0.9)
# Out:
# key1
# a    1.074959
# b    1.057046
# Name: data1, dtype: float64

# %%
def peak_to_peak(arr):
    return arr.max() - arr.min()

# %%
grouped.agg(peak_to_peak)
# Out:
#          data1     data2
# key1
# a     0.962554  0.816387
# b     1.857847  1.807945

# %%
grouped.describe()
# Out:
#      data1                                                              \
#      count      mean       std       min       25%       50%       75%
# key1
# a      3.0  0.737031  0.522696  0.138021  0.555260  0.972499  1.036536
# b      2.0  0.313907  1.313696 -0.615016 -0.150555  0.313907  0.778369
#
#                data2                                                    \
#            max count      mean       std       min       25%       50%
# key1
# a     1.100574   3.0  0.442573  0.417376  0.084650  0.213342  0.342033
# b     1.242830   2.0 -0.184336  1.278410 -1.088308 -0.636322 -0.184336
#
#
#            75%       max
# key1
# a     0.621535  0.901036
# b     0.267651  0.719637

# %%
tips = pd.read_csv('ch08/tips.csv')

# %%
tips['tip_pct'] = tips['tip'] / tips['total_bill']

# %%
tips[:6]
# Out:
#    total_bill   tip     sex smoker  day    time  size   tip_pct
# 0       16.99  1.01  Female     No  Sun  Dinner     2  0.059447
# 1       10.34  1.66    Male     No  Sun  Dinner     3  0.160542
# 2       21.01  3.50    Male     No  Sun  Dinner     3  0.166587
# 3       23.68  3.31    Male     No  Sun  Dinner     2  0.139780
# 4       24.59  3.61  Female     No  Sun  Dinner     4  0.146808
# 5       25.29  4.71    Male     No  Sun  Dinner     4  0.186240

# %%
grouped = tips.groupby(['sex', 'smoker'])

# %%
grouped_pct = grouped['tip_pct']

# %%
grouped_pct.agg('mean')
# Out:
# sex     smoker
# Female  No        0.156921
#         Yes       0.182150
# Male    No        0.160669
#         Yes       0.152771
# Name: tip_pct, dtype: float64

# %%
grouped_pct.agg(['mean', 'std', peak_to_peak])
# Out:
#                    mean       std  peak_to_peak
# sex    smoker
# Female No      0.156921  0.036421      0.195876
#        Yes     0.182150  0.071595      0.360233
# Male   No      0.160669  0.041849      0.220186
#        Yes     0.152771  0.090588      0.674707

# %%
grouped_pct.agg([('foo', 'mean'), ('bar', np.std)])
# Out:
#                     foo       bar
# sex    smoker
# Female No      0.156921  0.036421
#        Yes     0.182150  0.071595
# Male   No      0.160669  0.041849
#        Yes     0.152771  0.090588

# %%
functions = ['count', 'mean', 'max']

# %%
result = grouped['tip_pct', 'total_bill'].agg(functions)

# %%
result
# Out:
#               tip_pct                     total_bill
#                 count      mean       max      count       mean    max
# sex    smoker
# Female No          54  0.156921  0.252672         54  18.105185  35.83
#        Yes         33  0.182150  0.416667         33  17.977879  44.30
# Male   No          97  0.160669  0.291990         97  19.791237  48.33
#        Yes         60  0.152771  0.710345         60  22.284500  50.81

# %%
result['tip_pct']
# Out:
#                count      mean       max
# sex    smoker
# Female No         54  0.156921  0.252672
#        Yes        33  0.182150  0.416667
# Male   No         97  0.160669  0.291990
#        Yes        60  0.152771  0.710345

# %%
ftuples = [('Durchschnitt', 'mean'), ('Abweichung', np.var)]

# %%
grouped['tip_pct', 'total_bill'].agg(ftuples)
# Out:
#                    tip_pct              total_bill
#               Durchschnitt Abweichung Durchschnitt Abweichung
# sex    smoker
# Female No         0.156921   0.001327    18.105185  53.092422
#        Yes        0.182150   0.005126    17.977879  84.451517
# Male   No         0.160669   0.001751    19.791237  76.152961
#        Yes        0.152771   0.008206    22.284500  98.244673

# %%
grouped.agg({'tip' : np.max, 'size' : 'sum'})
# Out:
#                 tip  size
# sex    smoker
# Female No       5.2   140
#        Yes      6.5    74
# Male   No       9.0   263
#        Yes     10.0   150

# %%
grouped.agg({'tip_pct' : ['min', 'max', 'mean', 'std'],'size' : 'sum'})
# Out:
#                 tip_pct                               size
#                     min       max      mean       std  sum
# sex    smoker
# Female No      0.056797  0.252672  0.156921  0.036421  140
#        Yes     0.056433  0.416667  0.182150  0.071595   74
# Male   No      0.071804  0.291990  0.160669  0.041849  263
#        Yes     0.035638  0.710345  0.152771  0.090588  150

# %%
tips.groupby(['sex', 'smoker'], as_index=False).mean()
# Out:
#       sex smoker  total_bill       tip      size   tip_pct
# 0  Female     No   18.105185  2.773519  2.592593  0.156921
# 1  Female    Yes   17.977879  2.931515  2.242424  0.182150
# 2    Male     No   19.791237  3.113402  2.711340  0.160669
# 3    Male    Yes   22.284500  3.051167  2.500000  0.152771

# %%
df
# Out:
#   key1 key2     data1     data2
# 0    a  one  0.972499  0.901036
# 1    a  two  1.100574  0.342033
# 2    b  one  1.242830  0.719637
# 3    b  two -0.615016 -1.088308
# 4    a  one  0.138021  0.084650

# %%
k1_means = df.groupby('key1').mean().add_prefix('mean_')

# %%
k1_means
# Out:
#       mean_data1  mean_data2
# key1
# a       0.737031    0.442573
# b       0.313907   -0.184336

# %%
pd.merge(df, k1_means, left_on='key1', right_index=True)
# Out:
#   key1 key2     data1     data2  mean_data1  mean_data2
# 0    a  one  0.972499  0.901036    0.737031    0.442573
# 1    a  two  1.100574  0.342033    0.737031    0.442573
# 4    a  one  0.138021  0.084650    0.737031    0.442573
# 2    b  one  1.242830  0.719637    0.313907   -0.184336
# 3    b  two -0.615016 -1.088308    0.313907   -0.184336

# %%
key = ['one', 'two', 'one', 'two', 'one']

# %%
people.groupby(key).mean()
# Out:
#             a         b         c         d         e
# one  0.021379 -0.627237 -0.774321  0.566309 -0.217569
# two -1.806272  0.276988 -1.038808  0.699523 -0.397849

# %%
people.groupby(key).transform(np.mean)
# Out:
#                a         b         c         d         e
# Joe     0.021379 -0.627237 -0.774321  0.566309 -0.217569
# Steve  -1.806272  0.276988 -1.038808  0.699523 -0.397849
# Wes     0.021379 -0.627237 -0.774321  0.566309 -0.217569
# Jim    -1.806272  0.276988 -1.038808  0.699523 -0.397849
# Travis  0.021379 -0.627237 -0.774321  0.566309 -0.217569

# %%
def demean(arr):
    return arr - arr.mean()

# %%
demeaned = people.groupby(key).transform(demean)

# %%
demeaned
# Out:
#                a         b         c         d         e
# Joe    -0.890300 -0.805457 -0.304739  0.012437  0.544050
# Steve   0.598427 -0.019085 -0.078153  0.487920 -0.390401
# Wes    -0.489278       NaN       NaN  0.407580  1.109736
# Jim    -0.598427  0.019085  0.078153 -0.487920  0.390401
# Travis  1.379578  0.805457  0.304739 -0.420017 -1.653786

# %%
demeaned.groupby(key).mean()
# Out:
#        a             b             c             d    e
# one  0.0  0.000000e+00  2.775558e-17  3.700743e-17  0.0
# two  0.0 -2.775558e-17  5.551115e-17  5.551115e-17  0.0

# %%
def top(df, n=5, column='tip_pct'):
    return df.sort_values(by=column)[-n:]

# %%
top(tips, n=6)
# Out:
#      total_bill   tip     sex smoker  day    time  size   tip_pct
# 109       14.31  4.00  Female    Yes  Sat  Dinner     2  0.279525
# 183       23.17  6.50    Male    Yes  Sun  Dinner     4  0.280535
# 232       11.61  3.39    Male     No  Sat  Dinner     2  0.291990
# 67         3.07  1.00  Female    Yes  Sat  Dinner     1  0.325733
# 178        9.60  4.00  Female    Yes  Sun  Dinner     2  0.416667
# 172        7.25  5.15    Male    Yes  Sun  Dinner     2  0.710345

# %%
tips.groupby('smoker').apply(top)
# Out:
#             total_bill   tip     sex smoker   day    time  size   tip_pct
# smoker
# No     88        24.71  5.85    Male     No  Thur   Lunch     2  0.236746
#        185       20.69  5.00    Male     No   Sun  Dinner     5  0.241663
#        51        10.29  2.60  Female     No   Sun  Dinner     2  0.252672
#        149        7.51  2.00    Male     No  Thur   Lunch     2  0.266312
#        232       11.61  3.39    Male     No   Sat  Dinner     2  0.291990
# Yes    109       14.31  4.00  Female    Yes   Sat  Dinner     2  0.279525
#        183       23.17  6.50    Male    Yes   Sun  Dinner     4  0.280535
#        67         3.07  1.00  Female    Yes   Sat  Dinner     1  0.325733
#        178        9.60  4.00  Female    Yes   Sun  Dinner     2  0.416667
#        172        7.25  5.15    Male    Yes   Sun  Dinner     2  0.710345

# %%
tips.groupby(['smoker', 'day']).apply(top, n=1, column='total_bill')
# Out:
#                  total_bill    tip     sex smoker   day    time  size  \
# smoker day
# No     Fri  94        22.75   3.25  Female     No   Fri  Dinner     2
#        Sat  212       48.33   9.00    Male     No   Sat  Dinner     4
#        Sun  156       48.17   5.00    Male     No   Sun  Dinner     6
#        Thur 142       41.19   5.00    Male     No  Thur   Lunch     5
# Yes    Fri  95        40.17   4.73    Male    Yes   Fri  Dinner     4
#        Sat  170       50.81  10.00    Male    Yes   Sat  Dinner     3
#        Sun  182       45.35   3.50    Male    Yes   Sun  Dinner     3
#        Thur 197       43.11   5.00  Female    Yes  Thur   Lunch     4
#
#                   tip_pct
# smoker day
# No     Fri  94   0.142857
#        Sat  212  0.186220
#        Sun  156  0.103799
#        Thur 142  0.121389
# Yes    Fri  95   0.117750
#        Sat  170  0.196812
#        Sun  182  0.077178
#        Thur 197  0.115982

# %%
result = tips.groupby('smoker')['tip_pct'].describe()

# %%
result
# Out:
#         count      mean       std       min       25%       50%       75%  \
# smoker
# No      151.0  0.159328  0.039910  0.056797  0.136906  0.155625  0.185014
# Yes      93.0  0.163196  0.085119  0.035638  0.106771  0.153846  0.195059
#
#              max
# smoker
# No      0.291990
# Yes     0.710345

# %%
result.unstack('smoker')
# Out:
#        smoker
# count  No        151.000000
#        Yes        93.000000
# mean   No          0.159328
#        Yes         0.163196
# std    No          0.039910
#        Yes         0.085119
# min    No          0.056797
#        Yes         0.035638
# 25%    No          0.136906
#        Yes         0.106771
# 50%    No          0.155625
#        Yes         0.153846
# 75%    No          0.185014
#        Yes         0.195059
# max    No          0.291990
#        Yes         0.710345
# dtype: float64

# %%
tips.groupby('smoker', group_keys=False).apply(top)
# Out:
#      total_bill   tip     sex smoker   day    time  size   tip_pct
# 88        24.71  5.85    Male     No  Thur   Lunch     2  0.236746
# 185       20.69  5.00    Male     No   Sun  Dinner     5  0.241663
# 51        10.29  2.60  Female     No   Sun  Dinner     2  0.252672
# 149        7.51  2.00    Male     No  Thur   Lunch     2  0.266312
# 232       11.61  3.39    Male     No   Sat  Dinner     2  0.291990
# 109       14.31  4.00  Female    Yes   Sat  Dinner     2  0.279525
# 183       23.17  6.50    Male    Yes   Sun  Dinner     4  0.280535
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1  0.325733
# 178        9.60  4.00  Female    Yes   Sun  Dinner     2  0.416667
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2  0.710345

# %%
frame = pd.DataFrame({'data1': np.random.randn(1000),'data2': np.random.randn(1000)})

# %%
factor = pd.cut(frame.data1, 4)

# %%
factor[:10]
# Out:
# 0     (-1.268, 0.506]
# 1     (-1.268, 0.506]
# 2     (-1.268, 0.506]
# 3     (-1.268, 0.506]
# 4     (-1.268, 0.506]
# 5     (-1.268, 0.506]
# 6     (-1.268, 0.506]
# 7    (-3.049, -1.268]
# 8      (0.506, 2.279]
# 9     (-1.268, 0.506]
# Name: data1, dtype: category
# Categories (4, interval[float64]): [(-3.049, -1.268] < (-1.268, 0.506] < (0.506, 2.279] < (2.279, 4.053]]

# %%
def get_stats(group):
    return {'min': group.min(), 'max': group.max(),
    'count': group.count(), 'mean': group.mean()}

# %%
grouped = frame.data2.groupby(factor)

# %%
grouped.apply(get_stats).unstack()
# Out:
#                   count       max      mean       min
# data1
# (-3.049, -1.268]   98.0  2.668965 -0.023211 -2.387038
# (-1.268, 0.506]   590.0  3.142769 -0.051876 -3.816436
# (0.506, 2.279]    301.0  2.426240  0.014147 -2.543362
# (2.279, 4.053]     11.0  0.736020 -0.352340 -2.178887

# %%
grouping = pd.qcut(frame.data1, 10, labels=False)

# %%
grouped = frame.data2.groupby(grouping)

# %%
grouped.apply(get_stats).unstack()
# Out:
#        count       max      mean       min
# data1
# 0      100.0  2.668965 -0.015578 -2.387038
# 1      100.0  2.524176  0.008694 -2.021584
# 2      100.0  2.250461 -0.135538 -2.321652
# 3      100.0  1.944894  0.003961 -2.481262
# 4      100.0  2.630105 -0.020863 -3.816436
# 5      100.0  3.142769 -0.020181 -2.031927
# 6      100.0  2.059469 -0.208714 -2.222675
# 7      100.0  2.426240  0.059023 -2.108660
# 8      100.0  2.211171  0.003315 -2.543362
# 9      100.0  1.950346  0.000893 -2.313424

# %%
import numpy as np
import pandas as pd
s = pd.Series(np.random.randn(6))

# %%
s[::2] = np.nan

# %%
s
# Out:
# 0         NaN
# 1   -0.740334
# 2         NaN
# 3   -1.649971
# 4         NaN
# 5   -0.587241
# dtype: float64

# %%
s.fillna(s.mean())
# Out:
# 0   -0.992515
# 1   -0.740334
# 2   -0.992515
# 3   -1.649971
# 4   -0.992515
# 5   -0.587241
# dtype: float64

# %%
states = ['Ohio', 'New York', 'Vermont', 'Florida',
'Oregon', 'Nevada', 'California', 'Idaho']

# %%
group_key = ['East'] * 4 + ['West'] * 4

# %%
data = pd.Series(np.random.randn(8), index=states)

# %%
data[['Vermont', 'Nevada', 'Idaho']] = np.nan

# %%
data
# Out:
# Ohio          0.144370
# New York     -1.355104
# Vermont            NaN
# Florida       1.613038
# Oregon        1.439988
# Nevada             NaN
# California    1.153364
# Idaho              NaN
# dtype: float64

# %%
fill_mean = lambda g: g.fillna(g.mean())

# %%
data.groupby(group_key).apply(fill_mean)
# Out:
# Ohio          0.144370
# New York     -1.355104
# Vermont       0.134102
# Florida       1.613038
# Oregon        1.439988
# Nevada        1.296676
# California    1.153364
# Idaho         1.296676
# dtype: float64

# %%
fill_values = {'East': 0.5, 'West': -1}

# %%
fill_func = lambda g: g.fillna(fill_values[g.name])

# %%
data.groupby(group_key).apply(fill_func)
# Out:
# Ohio          0.144370
# New York     -1.355104
# Vermont       0.500000
# Florida       1.613038
# Oregon        1.439988
# Nevada       -1.000000
# California    1.153364
# Idaho        -1.000000
# dtype: float64

# %%
import pandas as pd
import numpy as np
suits = ['H', 'S', 'C', 'D']
card_val = (list(range(1, 11)) + ([10] * 3)) * 4
base_names = ['A'] + list(range(2, 11)) + ['J', 'K', 'Q']
cards = []
for suit in ['H', 'S', 'C', 'D']:
    cards.extend(str(num) + suit for num in base_names)
deck = pd.Series(card_val, index=cards)
print(range(1,11))
# Out:
# range(1, 11)

# %%
deck[:13]
# Out:
# AH      1
# 2H      2
# 3H      3
# 4H      4
# 5H      5
# 6H      6
# 7H      7
# 8H      8
# 9H      9
# 10H    10
# JH     10
# KH     10
# QH     10
# dtype: int64

# %%
def draw(deck, n=5):
    return deck.take(np.random.permutation(len(deck))[:n])

# %%
draw(deck)
# Out:
# 4D     4
# 9D     9
# KH    10
# 3D     3
# 9S     9
# dtype: int64

# %%
get_suit = lambda card: card[-1]

# %%
deck.groupby(get_suit).apply(draw, n=2)
# Out:
# C  AC     1
#    QC    10
# D  6D     6
#    8D     8
# H  8H     8
#    2H     2
# S  JS    10
#    AS     1
# dtype: int64

# %%
deck.groupby(get_suit, group_keys=False).apply(draw, n=2)
# Out:
# 4C      4
# 10C    10
# 6D      6
# 10D    10
# 2H      2
# 6H      6
# AS      1
# 7S      7
# dtype: int64

# %%
df = pd.DataFrame({'category': ['a', 'a', 'a', 'a', 'b', 'b', 'b', 'b'],'data': np.random.randn(8),'weights': np.random.rand(8)})

# %%
df
# Out:
#   category      data   weights
# 0        a -1.612825  0.243207
# 1        a  1.820120  0.821265
# 2        a -0.699926  0.358192
# 3        a  1.087836  0.272410
# 4        b -0.503286  0.938137
# 5        b  1.338011  0.790674
# 6        b  0.694738  0.631862
# 7        b -0.793089  0.264946

# %%
grouped = df.groupby('category')

# %%
get_wavg = lambda g: np.average(g['data'], weights=g['weights'])

# %%
grouped.apply(get_wavg)
# Out:
# category
# a    0.677364
# b    0.310263
# dtype: float64

# %%
close_px = pd.read_csv('ch09/stock_px.csv', parse_dates=True, index_col=0)

# %%
close_px
# Out:
#               AAPL   MSFT    XOM      SPX
# 2003-01-02    7.40  21.11  29.22   909.03
# 2003-01-03    7.45  21.14  29.24   908.59
# 2003-01-06    7.45  21.52  29.96   929.01
# 2003-01-07    7.43  21.93  28.95   922.93
# 2003-01-08    7.28  21.31  28.83   909.93
# 2003-01-09    7.34  21.93  29.44   927.57
# 2003-01-10    7.36  21.97  29.03   927.57
# 2003-01-13    7.32  22.16  28.91   926.26
# 2003-01-14    7.30  22.39  29.17   931.66
# 2003-01-15    7.22  22.11  28.77   918.22
# 2003-01-16    7.31  21.75  28.90   914.60
# 2003-01-17    7.05  20.22  28.60   901.78
# 2003-01-21    7.01  20.17  27.94   887.62
# 2003-01-22    6.94  20.04  27.58   878.36
# 2003-01-23    7.09  20.54  27.52   887.34
# 2003-01-24    6.90  19.59  26.93   861.40
# 2003-01-27    7.07  19.32  26.21   847.48
# 2003-01-28    7.29  19.18  26.90   858.54
# 2003-01-29    7.47  19.61  27.88   864.36
# 2003-01-30    7.16  18.95  27.37   844.61
# 2003-01-31    7.18  18.65  28.13   855.70
# 2003-02-03    7.33  19.08  28.52   860.32
# 2003-02-04    7.30  18.59  28.52   848.20
# 2003-02-05    7.22  18.45  28.11   843.59
# 2003-02-06    7.22  18.63  27.87   838.15
# 2003-02-07    7.07  18.30  27.66   829.69
# 2003-02-10    7.18  18.62  27.87   835.97
# 2003-02-11    7.18  18.25  27.67   829.20
# 2003-02-12    7.20  18.25  27.12   818.68
# 2003-02-13    7.27  18.46  27.47   817.37
# ...            ...    ...    ...      ...
# 2011-09-02  374.05  25.80  72.14  1173.97
# 2011-09-06  379.74  25.51  71.15  1165.24
# 2011-09-07  383.93  26.00  73.65  1198.62
# 2011-09-08  384.14  26.22  72.82  1185.90
# 2011-09-09  377.48  25.74  71.01  1154.23
# 2011-09-12  379.94  25.89  71.84  1162.27
# 2011-09-13  384.62  26.04  71.65  1172.87
# 2011-09-14  389.30  26.50  72.64  1188.68
# 2011-09-15  392.96  26.99  74.01  1209.11
# 2011-09-16  400.50  27.12  74.55  1216.01
# 2011-09-19  411.63  27.21  73.70  1204.09
# 2011-09-20  413.45  26.98  74.01  1202.09
# 2011-09-21  412.14  25.99  71.97  1166.76
# 2011-09-22  401.82  25.06  69.24  1129.56
# 2011-09-23  404.30  25.06  69.31  1136.43
# 2011-09-26  403.17  25.44  71.72  1162.95
# 2011-09-27  399.26  25.67  72.91  1175.38
# 2011-09-28  397.01  25.58  72.07  1151.06
# 2011-09-29  390.57  25.45  73.88  1160.40
# 2011-09-30  381.32  24.89  72.63  1131.42
# 2011-10-03  374.60  24.53  71.15  1099.23
# 2011-10-04  372.50  25.34  72.83  1123.95
# 2011-10-05  378.25  25.89  73.95  1144.03
# 2011-10-06  377.37  26.34  73.89  1164.97
# 2011-10-07  369.80  26.25  73.56  1155.46
# 2011-10-10  388.81  26.94  76.28  1194.89
# 2011-10-11  400.29  27.00  76.27  1195.54
# 2011-10-12  402.19  26.96  77.16  1207.25
# 2011-10-13  408.43  27.18  76.37  1203.66
# 2011-10-14  422.00  27.27  78.11  1224.58
#
# [2214 rows x 4 columns]

# %%
close_px[-4:]
# Out:
#               AAPL   MSFT    XOM      SPX
# 2011-10-11  400.29  27.00  76.27  1195.54
# 2011-10-12  402.19  26.96  77.16  1207.25
# 2011-10-13  408.43  27.18  76.37  1203.66
# 2011-10-14  422.00  27.27  78.11  1224.58

# %%
rets = close_px.pct_change().dropna()

# %%
spx_corr = lambda x: x.corrwith(x['SPX'])

# %%
by_year = rets.groupby(lambda x: x.year)

# %%
by_year.apply(spx_corr)
# Out:
#           AAPL      MSFT       XOM  SPX
# 2003  0.541124  0.745174  0.661265  1.0
# 2004  0.374283  0.588531  0.557742  1.0
# 2005  0.467540  0.562374  0.631010  1.0
# 2006  0.428267  0.406126  0.518514  1.0
# 2007  0.508118  0.658770  0.786264  1.0
# 2008  0.681434  0.804626  0.828303  1.0
# 2009  0.707103  0.654902  0.797921  1.0
# 2010  0.710105  0.730118  0.839057  1.0
# 2011  0.691931  0.800996  0.859975  1.0

# %%
by_year.apply(lambda g: g['AAPL'].corr(g['MSFT']))
# Out:
# 2003    0.480868
# 2004    0.259024
# 2005    0.300093
# 2006    0.161735
# 2007    0.417738
# 2008    0.611901
# 2009    0.432738
# 2010    0.571946
# 2011    0.581987
# dtype: float64

# %%
import statsmodels.api as sm
import pandas as pd
def regress(data, yvar, xvars):
    Y = data[yvar]
    X = data[xvars]
    X['intercept'] = 1.
    result = sm.OLS(Y, X).fit()
    return result.params

# %%
by_year.apply(regress, 'AAPL', ['SPX'])
# Out:
#            SPX  intercept
# 2003  1.195406   0.000710
# 2004  1.363463   0.004201
# 2005  1.766415   0.003246
# 2006  1.645496   0.000080
# 2007  1.198761   0.003438
# 2008  0.968016  -0.001110
# 2009  0.879103   0.002954
# 2010  1.052608   0.001261
# 2011  0.806605   0.001514

# %%
tips.pivot_table(index=['sex', 'smoker'])
# Out:
#                    size       tip   tip_pct  total_bill
# sex    smoker
# Female No      2.592593  2.773519  0.156921   18.105185
#        Yes     2.242424  2.931515  0.182150   17.977879
# Male   No      2.711340  3.113402  0.160669   19.791237
#        Yes     2.500000  3.051167  0.152771   22.284500

# %%
tips.pivot_table(['tip_pct', 'size'], index=['sex', 'day'], columns='smoker')
# Out:
#                  size             tip_pct
# smoker             No       Yes        No       Yes
# sex    day
# Female Fri   2.500000  2.000000  0.165296  0.209129
#        Sat   2.307692  2.200000  0.147993  0.163817
#        Sun   3.071429  2.500000  0.165710  0.237075
#        Thur  2.480000  2.428571  0.155971  0.163073
# Male   Fri   2.000000  2.125000  0.138005  0.144730
#        Sat   2.656250  2.629630  0.162132  0.139067
#        Sun   2.883721  2.600000  0.158291  0.173964
#        Thur  2.500000  2.300000  0.165706  0.164417

# %%
tips.pivot_table('tip_pct', index=['sex', 'smoker'], columns='day',aggfunc=len, margins=True)
# Out:
# day             Fri   Sat   Sun  Thur    All
# sex    smoker
# Female No       2.0  13.0  14.0  25.0   54.0
#        Yes      7.0  15.0   4.0   7.0   33.0
# Male   No       2.0  32.0  43.0  20.0   97.0
#        Yes      8.0  27.0  15.0  10.0   60.0
# All            19.0  87.0  76.0  62.0  244.0

# %%
tips.pivot_table('size', index=['time', 'sex', 'smoker'],columns='day', aggfunc='sum', fill_value=0)
# Out:
# day                   Fri  Sat  Sun  Thur
# time   sex    smoker
# Dinner Female No        2   30   43     2
#               Yes       8   33   10     0
#        Male   No        4   85  124     0
#               Yes      12   71   39     0
# Lunch  Female No        3    0    0    60
#               Yes       6    0    0    17
#        Male   No        0    0    0    50
#               Yes       5    0    0    23

# %%
data = []
data
# Out:
# []

# %%
pd.crosstab(data.Gender, data.Handedness, margins=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-297-579f417e623e> in <module>
# ----> 1 pd.crosstab(data.Gender, data.Handedness, margins=True)
#
# AttributeError: 'list' object has no attribute 'Gender'

# %%
pd.crosstab([tips.time, tips.day], tips.smoker, margins=True)
# Out:
# smoker        No  Yes  All
# time   day
# Dinner Fri     3    9   12
#        Sat    45   42   87
#        Sun    57   19   76
#        Thur    1    0    1
# Lunch  Fri     1    6    7
#        Thur   44   17   61
# All          151   93  244

# %%
fec = pd.read_csv('ch09/P00000001-ALL.csv')
# Out:
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
fec
# Out:
#            cmte_id    cand_id             cand_nm  \
# 0        C00410118  P20002978  Bachmann, Michelle
# 1        C00410118  P20002978  Bachmann, Michelle
# 2        C00410118  P20002978  Bachmann, Michelle
# 3        C00410118  P20002978  Bachmann, Michelle
# 4        C00410118  P20002978  Bachmann, Michelle
# 5        C00410118  P20002978  Bachmann, Michelle
# 6        C00410118  P20002978  Bachmann, Michelle
# 7        C00410118  P20002978  Bachmann, Michelle
# 8        C00410118  P20002978  Bachmann, Michelle
# 9        C00410118  P20002978  Bachmann, Michelle
# 10       C00410118  P20002978  Bachmann, Michelle
# 11       C00410118  P20002978  Bachmann, Michelle
# 12       C00410118  P20002978  Bachmann, Michelle
# 13       C00410118  P20002978  Bachmann, Michelle
# 14       C00410118  P20002978  Bachmann, Michelle
# 15       C00410118  P20002978  Bachmann, Michelle
# 16       C00410118  P20002978  Bachmann, Michelle
# 17       C00410118  P20002978  Bachmann, Michelle
# 18       C00410118  P20002978  Bachmann, Michelle
# 19       C00410118  P20002978  Bachmann, Michelle
# 20       C00410118  P20002978  Bachmann, Michelle
# 21       C00410118  P20002978  Bachmann, Michelle
# 22       C00410118  P20002978  Bachmann, Michelle
# 23       C00410118  P20002978  Bachmann, Michelle
# 24       C00410118  P20002978  Bachmann, Michelle
# 25       C00410118  P20002978  Bachmann, Michelle
# 26       C00410118  P20002978  Bachmann, Michelle
# 27       C00410118  P20002978  Bachmann, Michelle
# 28       C00410118  P20002978  Bachmann, Michelle
# 29       C00410118  P20002978  Bachmann, Michelle
# ...            ...        ...                 ...
# 1001701  C00500587  P20003281         Perry, Rick
# 1001702  C00500587  P20003281         Perry, Rick
# 1001703  C00500587  P20003281         Perry, Rick
# 1001704  C00500587  P20003281         Perry, Rick
# 1001705  C00500587  P20003281         Perry, Rick
# 1001706  C00500587  P20003281         Perry, Rick
# 1001707  C00500587  P20003281         Perry, Rick
# 1001708  C00500587  P20003281         Perry, Rick
# 1001709  C00500587  P20003281         Perry, Rick
# 1001710  C00500587  P20003281         Perry, Rick
# 1001711  C00500587  P20003281         Perry, Rick
# 1001712  C00500587  P20003281         Perry, Rick
# 1001713  C00500587  P20003281         Perry, Rick
# 1001714  C00500587  P20003281         Perry, Rick
# 1001715  C00500587  P20003281         Perry, Rick
# 1001716  C00500587  P20003281         Perry, Rick
# 1001717  C00500587  P20003281         Perry, Rick
# 1001718  C00500587  P20003281         Perry, Rick
# 1001719  C00500587  P20003281         Perry, Rick
# 1001720  C00500587  P20003281         Perry, Rick
# 1001721  C00500587  P20003281         Perry, Rick
# 1001722  C00500587  P20003281         Perry, Rick
# 1001723  C00500587  P20003281         Perry, Rick
# 1001724  C00500587  P20003281         Perry, Rick
# 1001725  C00500587  P20003281         Perry, Rick
# 1001726  C00500587  P20003281         Perry, Rick
# 1001727  C00500587  P20003281         Perry, Rick
# 1001728  C00500587  P20003281         Perry, Rick
# 1001729  C00500587  P20003281         Perry, Rick
# 1001730  C00500587  P20003281         Perry, Rick
#
#                            contbr_nm         contbr_city contbr_st  \
# 0                    HARVEY, WILLIAM              MOBILE        AL
# 1                    HARVEY, WILLIAM              MOBILE        AL
# 2                      SMITH, LANIER              LANETT        AL
# 3                   BLEVINS, DARONDA             PIGGOTT        AR
# 4                 WARDENBURG, HAROLD  HOT SPRINGS NATION        AR
# 5                     BECKMAN, JAMES          SPRINGDALE        AR
# 6                   BLEVINS, DARONDA             PIGGOTT        AR
# 7                   BLEVINS, DARONDA             PIGGOTT        AR
# 8                     COLLINS, SARAH                MESA        AZ
# 9                    COLEMAN, RONALD              TUCSON        AZ
# 10                ATCHLEY, JR, KEITH                MESA        AZ
# 11                  FARNSWORTH, ROSS                MESA        AZ
# 12                 PRESTON, CLIFFORD          ORO VALLEY        AZ
# 13                       PETERSEN, W             GILBERT        AZ
# 14                   MILLER, WILLIAM          SCOTTSDALE        AZ
# 15                    DOLAN, WILLIAM             PHOENIX        AZ
# 16                   WILSON, RICHARD           FLAGSTAFF        AZ
# 17                  REULING, RICHARD        GREEN VALLEY        AZ
# 18                 ALLUMBAUGH, KATHY           SANTA ANA        CA
# 19                    DEL POZO, JOSE             DEL MAR        CA
# 20                   KIEFFER, PIERRE          SACRAMENTO        CA
# 21                   HANNAH, STEPHEN        SHERMAN OAKS        CA
# 22                      MINNIS, RITA            MILPITAS        CA
# 23                      MINNIS, RITA            MILPITAS        CA
# 24                     EDWARDS, MARK            LA JOLLA        CA
# 25                   HANNAH, STEPHEN        SHERMAN OAKS        CA
# 26                       HENRY, JOAN           YUBA CITY        CA
# 27                    SKEREN, THOMAS           CALABASAS        CA
# 28                  EDWARDS, WILLIAM         LOS ANGELES        CA
# 29                     PORTER, NANCY       CARMEL VALLEY        CA
# ...                              ...                 ...       ...
# 1001701         NELSON, DEBORAH MRS.          MORGANTOWN        WV
# 1001702       PHILLIPS, JIMMY D. MR.             BECKLEY        WV
# 1001703        NELSON, HOWARD L. MR.          MORGANTOWN        WV
# 1001704       PHILLIPS, JIMMY D. MR.             BECKLEY        WV
# 1001705       PATTON, CHARLES R. MR.          CHARLESTON        WV
# 1001706     BEVILOCK, DEBBIE S. MRS.             GRAFTON        WV
# 1001707        BEVILOCK, JOHN C. MR.             GRAFTON        WV
# 1001708    HAYHURST, CYNTHIA L. MRS.            WHEELING        WV
# 1001709       HAYHURST, JAMES W. MR.            WHEELING        WV
# 1001710              PHILLIPS, JIMMY             BECKLEY        WV
# 1001711          FRIESS, STEPHEN MR.             JACKSON        WY
# 1001712       SUGDEN, RICHARD G. MR.             JACKSON        WY
# 1001713           SUGDEN, SUSAN MRS.             JACKSON        WY
# 1001714              SPENCE, RUSSELL            RIVERTON        WY
# 1001715          TEXAS ENERGY L.L.C.            CHEYENNE        WY
# 1001716                 KINSEY, JOAN             LARAMIE        WY
# 1001717               HARDER, ROBERT              POWELL        WY
# 1001718                   LUCAS, WES       TETON VILLAGE        WY
# 1001719              LUCAS, ELISABET       TETON VILLAGE        WY
# 1001720               HARDER, ROBERT              POWELL        WY
# 1001721            HANSEN, STEVE MR.            CHEYENNE        WY
# 1001722               HARDER, ROBERT              POWELL        WY
# 1001723               HARDER, ROBERT              POWELL        WY
# 1001724  HEFFERNAN, JILL PRINCE MRS.      INFO REQUESTED        XX
# 1001725             ELWOOD, MIKE MR.      INFO REQUESTED        XX
# 1001726         GORMAN, CHRIS D. MR.      INFO REQUESTED        XX
# 1001727          DUFFY, DAVID A. MR.      INFO REQUESTED        XX
# 1001728          GRANE, BRYAN F. MR.      INFO REQUESTED        XX
# 1001729           TOLBERT, DARYL MR.      INFO REQUESTED        XX
# 1001730       ANDERSON, MARILEE MRS.      INFO REQUESTED        XX
#
#           contbr_zip                         contbr_employer  \
# 0         3.6601e+08                                 RETIRED
# 1         3.6601e+08                                 RETIRED
# 2        3.68633e+08                   INFORMATION REQUESTED
# 3        7.24548e+08                                    NONE
# 4        7.19016e+08                                    NONE
# 5        7.27647e+08                                    NONE
# 6        7.24548e+08                   INFORMATION REQUESTED
# 7        7.24548e+08                                    NONE
# 8        8.52107e+08                     ST. JOSEPH HOSPITAL
# 9        8.57499e+08                                RAYTHEON
# 10             85215                                    NONE
# 11       8.52062e+08                    FARNSWORTH COMPANIES
# 12       8.57379e+08                   INFORMATION REQUESTED
# 13             85295                   INFORMATION REQUESTED
# 14       8.52513e+08                   INFORMATION REQUESTED
# 15       8.50145e+08                       VA MEDICAL CENTER
# 16       8.60011e+08                                    NONE
# 17       8.56225e+08                                    NONE
# 18       9.27051e+08                                    NONE
# 19       9.20143e+08                                 RETIRES
# 20       9.58257e+08                                    SELF
# 21       9.14132e+08                                 RETIRED
# 22       9.50358e+08                       MILPITS MATERIALS
# 23       9.50358e+08                       MILPITS MATERIALS
# 24       9.20378e+08                                    NONE
# 25       9.14132e+08                                    NONE
# 26       9.59939e+08                                    NONE
# 27       9.13022e+08                   INFORMATION REQUESTED
# 28       9.00243e+08                   INFORMATION REQUESTED
# 29       9.39249e+08                            NANCY PORTER
# ...              ...                                     ...
# 1001701    265082541                               HOMEMAKER
# 1001702    258011601               PHILLIPS MACHINE SERVICES
# 1001703    265082541                      SWANSON INDUSTRIES
# 1001704    258011601               PHILLIPS MACHINE SERVICES
# 1001705    253142370  INFORMATION REQUESTED PER BEST EFFORTS
# 1001706    263549332  INFORMATION REQUESTED PER BEST EFFORTS
# 1001707    263549332                   DAVID STANLEY COMPANY
# 1001708    260035764  INFORMATION REQUESTED PER BEST EFFORTS
# 1001709    260035764                   DAVID STANLEY COMPANY
# 1001710        25801                                     NaN
# 1001711    830021655                             FRIESS INC.
# 1001712    830010489              FAMILY PRACTICE ASSOCIATES
# 1001713    830010489                           SELF-EMPLOYED
# 1001714    825019711  INFORMATION REQUESTED PER BEST EFFORTS
# 1001715    820013163                                     NaN
# 1001716    820709758                                 RETIRED
# 1001717    824359238                                     NaN
# 1001718        83025                                   SIRVA
# 1001719    830250824                        LUCAS PROPERTIES
# 1001720    824359238                                     NaN
# 1001721    820013163                        TEXAS ENERGY LLC
# 1001722    824359238                                     NaN
# 1001723    824359238                                     NaN
# 1001724        99999  INFORMATION REQUESTED PER BEST EFFORTS
# 1001725        99999                                 AM COAL
# 1001726        99999  INFORMATION REQUESTED PER BEST EFFORTS
# 1001727        99999            DUFFY EQUIPMENT COMPANY INC.
# 1001728        99999  INFORMATION REQUESTED PER BEST EFFORTS
# 1001729        99999                                T.A.C.C.
# 1001730        99999  INFORMATION REQUESTED PER BEST EFFORTS
#
#                               contbr_occupation  contb_receipt_amt  \
# 0                                       RETIRED              250.0
# 1                                       RETIRED               50.0
# 2                         INFORMATION REQUESTED              250.0
# 3                                       RETIRED              250.0
# 4                                       RETIRED              300.0
# 5                                       RETIRED              500.0
# 6                         INFORMATION REQUESTED              250.0
# 7                                       RETIRED              250.0
# 8                                            RN              250.0
# 9                           ELECTRICAL ENGINEER              250.0
# 10                                      RETIRED              250.0
# 11                               LAND DEVELOPER              500.0
# 12                        INFORMATION REQUESTED              250.0
# 13                        INFORMATION REQUESTED              250.0
# 14                        INFORMATION REQUESTED              250.0
# 15                                    PHYSICIAN              300.0
# 16                                      RETIRED              500.0
# 17                                      RETIRED             1000.0
# 18                                      RETIRED              250.0
# 19                                      RETIRED              300.0
# 20                      OFFICE FURNITURE BROKER              500.0
# 21                                      RETIRED              250.0
# 22                                      MANAGER             2500.0
# 23                                      MANAGER             2500.0
# 24                                      RETIRED              150.0
# 25                                      RETIRED              200.0
# 26                                      RETIRED              100.0
# 27                        INFORMATION REQUESTED              250.0
# 28                        INFORMATION REQUESTED              500.0
# 29                                      REALTOR              250.0
# ...                                         ...                ...
# 1001701                               HOMEMAKER             2500.0
# 1001702                               EXECUTIVE             2500.0
# 1001703                                  C.F.O.            -2500.0
# 1001704                               EXECUTIVE            -2500.0
# 1001705  INFORMATION REQUESTED PER BEST EFFORTS             1000.0
# 1001706  INFORMATION REQUESTED PER BEST EFFORTS             2500.0
# 1001707                                   SALES            -2500.0
# 1001708  INFORMATION REQUESTED PER BEST EFFORTS             2500.0
# 1001709                                   SALES            -2500.0
# 1001710                                     NaN            -2500.0
# 1001711                              CONSULTANT             1000.0
# 1001712                                  DOCTOR             2500.0
# 1001713                                INVESTOR             2500.0
# 1001714  INFORMATION REQUESTED PER BEST EFFORTS              250.0
# 1001715                                     NaN              250.0
# 1001716                                 RETIRED             1000.0
# 1001717                                 RETIRED              100.0
# 1001718                                     CEO             2500.0
# 1001719                                   OWNER             2500.0
# 1001720                                 RETIRED              100.0
# 1001721                               EXECUTIVE              250.0
# 1001722                                 RETIRED              100.0
# 1001723                                 RETIRED              100.0
# 1001724  INFORMATION REQUESTED PER BEST EFFORTS              500.0
# 1001725                                ENGINEER             2500.0
# 1001726  INFORMATION REQUESTED PER BEST EFFORTS             5000.0
# 1001727                          BUSINESS OWNER             2500.0
# 1001728  INFORMATION REQUESTED PER BEST EFFORTS              500.0
# 1001729            LONGWALL MAINTENANCE FOREMAN              500.0
# 1001730  INFORMATION REQUESTED PER BEST EFFORTS             2500.0
#
#         contb_receipt_dt                                       receipt_desc  \
# 0              20-JUN-11                                                NaN
# 1              23-JUN-11                                                NaN
# 2              05-JUL-11                                                NaN
# 3              01-AUG-11                                                NaN
# 4              20-JUN-11                                                NaN
# 5              23-JUN-11                                                NaN
# 6              21-JUN-11                                                NaN
# 7              05-JUL-11                                                NaN
# 8              21-JUN-11                                                NaN
# 9              20-JUN-11                                                NaN
# 10             22-JUN-11                                                NaN
# 11             22-JUN-11                                                NaN
# 12             21-JUN-11                                                NaN
# 13             27-JUN-11                                                NaN
# 14             11-JUL-11                                                NaN
# 15             08-JUL-11                                                NaN
# 16             17-JUN-11                                                NaN
# 17             05-JUL-11                                                NaN
# 18             13-JUN-11                                                NaN
# 19             16-JUN-11                                                NaN
# 20             16-JUN-11                                                NaN
# 21             16-JUN-11                                                NaN
# 22             17-JUN-11                                                NaN
# 23             17-JUN-11                                                NaN
# 24             05-AUG-11                                                NaN
# 25             08-AUG-11                                                NaN
# 26             15-AUG-11                                                NaN
# 27             16-AUG-11                                                NaN
# 28             18-AUG-11                                                NaN
# 29             05-JUL-11                                                NaN
# ...                  ...                                                ...
# 1001701        01-OCT-11                          REATTRIBUTION FROM SPOUSE
# 1001702        28-NOV-11                         REDESIGNATION FROM PRIMARY
# 1001703        01-OCT-11                            REATTRIBUTION TO SPOUSE
# 1001704        28-NOV-11                           REDESIGNATION TO GENERAL
# 1001705        17-NOV-11                                                NaN
# 1001706        08-OCT-11                          REATTRIBUTION FROM SPOUSE
# 1001707        08-OCT-11                            REATTRIBUTION TO SPOUSE
# 1001708        09-OCT-11                          REATTRIBUTION FROM SPOUSE
# 1001709        09-OCT-11                            REATTRIBUTION TO SPOUSE
# 1001710        31-MAR-12                                             Refund
# 1001711        29-SEP-11                                                NaN
# 1001712        26-AUG-11                                                NaN
# 1001713        26-AUG-11                                                NaN
# 1001714        15-AUG-11                                                NaN
# 1001715        30-SEP-11                                                NaN
# 1001716        17-AUG-11                                                NaN
# 1001717        12-NOV-11                                                NaN
# 1001718        04-OCT-11                                                NaN
# 1001719        04-OCT-11                                                NaN
# 1001720        01-OCT-11                                                NaN
# 1001721        15-NOV-11                                                NaN
# 1001722        29-OCT-11                                                NaN
# 1001723        30-NOV-11                                                NaN
# 1001724        30-SEP-11                                                NaN
# 1001725        30-SEP-11                                                NaN
# 1001726        29-SEP-11  REATTRIBUTION / REDESIGNATION REQUESTED (AUTOM...
# 1001727        30-SEP-11                                                NaN
# 1001728        29-SEP-11                                                NaN
# 1001729        30-SEP-11                                                NaN
# 1001730        31-AUG-11                                                NaN
#
#         memo_cd                                          memo_text form_tp  \
# 0           NaN                                                NaN   SA17A
# 1           NaN                                                NaN   SA17A
# 2           NaN                                                NaN   SA17A
# 3           NaN                                                NaN   SA17A
# 4           NaN                                                NaN   SA17A
# 5           NaN                                                NaN   SA17A
# 6           NaN                                                NaN   SA17A
# 7           NaN                                                NaN   SA17A
# 8           NaN                                                NaN   SA17A
# 9           NaN                                                NaN   SA17A
# 10          NaN                                                NaN   SA17A
# 11          NaN                                                NaN   SA17A
# 12          NaN                                                NaN   SA17A
# 13          NaN                                                NaN   SA17A
# 14          NaN                                                NaN   SA17A
# 15          NaN                                                NaN   SA17A
# 16          NaN                                                NaN   SA17A
# 17          NaN                                                NaN   SA17A
# 18          NaN                                                NaN   SA17A
# 19          NaN                                                NaN   SA17A
# 20          NaN                                                NaN   SA17A
# 21          NaN                                                NaN   SA17A
# 22          NaN                                                NaN   SA17A
# 23          NaN                                                NaN   SA17A
# 24          NaN                                                NaN   SA17A
# 25          NaN                                                NaN   SA17A
# 26          NaN                                                NaN   SA17A
# 27          NaN                                                NaN   SA17A
# 28          NaN                                                NaN   SA17A
# 29          NaN                                                NaN   SA17A
# ...         ...                                                ...     ...
# 1001701       X                          REATTRIBUTION FROM SPOUSE   SA17A
# 1001702       X                         REDESIGNATION FROM PRIMARY   SA17A
# 1001703       X                            REATTRIBUTION TO SPOUSE   SA17A
# 1001704       X                           REDESIGNATION TO GENERAL   SA17A
# 1001705     NaN                                                NaN   SA17A
# 1001706       X                          REATTRIBUTION FROM SPOUSE   SA17A
# 1001707       X                            REATTRIBUTION TO SPOUSE   SA17A
# 1001708       X                          REATTRIBUTION FROM SPOUSE   SA17A
# 1001709       X                            REATTRIBUTION TO SPOUSE   SA17A
# 1001710     NaN                                     GENERAL REFUND   SB28A
# 1001711     NaN                                                NaN   SA17A
# 1001712     NaN                                                NaN   SA17A
# 1001713     NaN                                                NaN   SA17A
# 1001714     NaN                                                NaN   SA17A
# 1001715     NaN                  ATTRIBUTION TO PARTNERS REQUESTED   SA17A
# 1001716     NaN                                                NaN   SA17A
# 1001717     NaN                                                NaN   SA17A
# 1001718     NaN                                                NaN   SA17A
# 1001719     NaN                                                NaN   SA17A
# 1001720     NaN                                                NaN   SA17A
# 1001721       X                                    SEE ATTRIBUTION   SA17A
# 1001722     NaN                                                NaN   SA17A
# 1001723     NaN                                                NaN   SA17A
# 1001724     NaN                                                NaN   SA17A
# 1001725     NaN                                                NaN   SA17A
# 1001726     NaN  REATTRIBUTION / REDESIGNATION REQUESTED (AUTOM...   SA17A
# 1001727     NaN                                                NaN   SA17A
# 1001728     NaN                                                NaN   SA17A
# 1001729     NaN                                                NaN   SA17A
# 1001730     NaN                                                NaN   SA17A
#
#          file_num
# 0          736166
# 1          736166
# 2          749073
# 3          749073
# 4          736166
# 5          736166
# 6          736166
# 7          749073
# 8          736166
# 9          736166
# 10         736166
# 11         736166
# 12         736166
# 13         736166
# 14         749073
# 15         749073
# 16         736166
# 17         749073
# 18         736166
# 19         736166
# 20         736166
# 21         736166
# 22         736166
# 23         736166
# 24         749073
# 25         749073
# 26         749073
# 27         749073
# 28         749073
# 29         749073
# ...           ...
# 1001701    772060
# 1001702    772060
# 1001703    772060
# 1001704    772060
# 1001705    772060
# 1001706    772060
# 1001707    772060
# 1001708    772060
# 1001709    772060
# 1001710    779144
# 1001711    751678
# 1001712    751678
# 1001713    751678
# 1001714    751678
# 1001715    751678
# 1001716    751678
# 1001717    772060
# 1001718    772060
# 1001719    772060
# 1001720    772060
# 1001721    772060
# 1001722    772060
# 1001723    772060
# 1001724    751678
# 1001725    751678
# 1001726    751678
# 1001727    751678
# 1001728    751678
# 1001729    751678
# 1001730    751678
#
# [1001731 rows x 16 columns]

# %%
fec.loc[123456]
# Out:
# cmte_id                             C00431445
# cand_id                             P80003338
# cand_nm                         Obama, Barack
# contbr_nm                         ELLMAN, IRA
# contbr_city                             TEMPE
# contbr_st                                  AZ
# contbr_zip                          852816719
# contbr_employer      ARIZONA STATE UNIVERSITY
# contbr_occupation                   PROFESSOR
# contb_receipt_amt                          50
# contb_receipt_dt                    01-DEC-11
# receipt_desc                              NaN
# memo_cd                                   NaN
# memo_text                                 NaN
# form_tp                                 SA17A
# file_num                               772372
# Name: 123456, dtype: object

# %%
unique_cands = fec.cand_nm.unique()

# %%
unique_cands
# Out:
# array(['Bachmann, Michelle', 'Romney, Mitt', 'Obama, Barack',
#        "Roemer, Charles E. 'Buddy' III", 'Pawlenty, Timothy',
#        'Johnson, Gary Earl', 'Paul, Ron', 'Santorum, Rick',
#        'Cain, Herman', 'Gingrich, Newt', 'McCotter, Thaddeus G',
#        'Huntsman, Jon', 'Perry, Rick'], dtype=object)

# %%
unique_cands[2]
# Out:
# 'Obama, Barack'

# %%
fec.cand_nm[123456:123461]
# Out:
# 123456    Obama, Barack
# 123457    Obama, Barack
# 123458    Obama, Barack
# 123459    Obama, Barack
# 123460    Obama, Barack
# Name: cand_nm, dtype: object

# %%
parties = {'Bachmann, Michelle': 'Republican',
'Cain, Herman': 'Republican',
'Gingrich, Newt': 'Republican',
'Huntsman, Jon': 'Republican',
'Johnson, Gary Earl': 'Republican',
'McCotter, Thaddeus G': 'Republican',
'Obama, Barack': 'Democrat',
'Paul, Ron': 'Republican',
'Pawlenty, Timothy': 'Republican',
'Perry, Rick': 'Republican',
"Roemer, Charles E. 'Buddy' III": 'Republican','Romney, Mitt': 'Republican',
'Santorum, Rick': 'Republican'}
fec.cand_nm[123456:123461].map(parties)
# Out:
# 123456    Democrat
# 123457    Democrat
# 123458    Democrat
# 123459    Democrat
# 123460    Democrat
# Name: cand_nm, dtype: object

# %%
fec['party'] = fec.cand_nm.map(parties)

# %%
fec['party'].value_counts()
# Out:
# Democrat      593746
# Republican    407985
# Name: party, dtype: int64

# %%
(fec.contb_receipt_amt > 0).value_counts()
# Out:
# True     991475
# False     10256
# Name: contb_receipt_amt, dtype: int64

# %%
fec = fec[fec.contb_receipt_amt > 0]

# %%
fec_mrbo = fec[fec.cand_nm.isin(['Obama, Barack', 'Romney, Mitt'])]

# %%
fec.contbr_occupation.value_counts()[:10]
# Out:
# RETIRED                                   233990
# INFORMATION REQUESTED                      35107
# ATTORNEY                                   34286
# HOMEMAKER                                  29931
# PHYSICIAN                                  23432
# INFORMATION REQUESTED PER BEST EFFORTS     21138
# ENGINEER                                   14334
# TEACHER                                    13990
# CONSULTANT                                 13273
# PROFESSOR                                  12555
# Name: contbr_occupation, dtype: int64

# %%
occ_mapping = {
'INFORMATION REQUESTED PER BEST EFFORTS' : 'NOT PROVIDED',
'INFORMATION REQUESTED' : 'NOT PROVIDED',
'INFORMATION REQUESTED (BEST EFFORTS)' : 'NOT PROVIDED',
'C.E.O.': 'CEO'
}
# If no mapping provided, return x
f = lambda x: occ_mapping.get(x, x)
fec.contbr_occupation = fec.contbr_occupation.map(f)
by_occupation = fec.pivot_table('contb_receipt_amt', index='contbr_occupation', columns='party', aggfunc='sum')
# Out:
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
over_2mm = by_occupation[by_occupation.sum(1) > 2000000]

# %%
over_2mm
# Out:
# party                 Democrat    Republican
# contbr_occupation
# ATTORNEY           11141982.97  7.477194e+06
# CEO                 2074974.79  4.211041e+06
# CONSULTANT          2459912.71  2.544725e+06
# ENGINEER             951525.55  1.818374e+06
# EXECUTIVE           1355161.05  4.138850e+06
# HOMEMAKER           4248875.80  1.363428e+07
# INVESTOR             884133.00  2.431769e+06
# LAWYER              3160478.87  3.912243e+05
# MANAGER              762883.22  1.444532e+06
# NOT PROVIDED        4866973.96  2.056547e+07
# OWNER               1001567.36  2.408287e+06
# PHYSICIAN           3735124.94  3.594320e+06
# PRESIDENT           1878509.95  4.720924e+06
# PROFESSOR           2165071.08  2.967027e+05
# REAL ESTATE          528902.09  1.625902e+06
# RETIRED            25305116.38  2.356124e+07
# SELF-EMPLOYED        672393.40  1.640253e+06

# %%
over_2mm.plot(kind='barh')

# %%
def get_top_amounts(group, key, n=5):
    totals = group.groupby(key)['contb_receipt_amt'].sum()
    #print(type(totals))
    return totals.sort_values(ascending=False)[-n:]

# %%
grouped = fec_mrbo.groupby('cand_nm')

# %%
grouped.apply(get_top_amounts, 'contbr_occupation', n=7)
# Out:
# cand_nm        contbr_occupation
# Obama, Barack  COMPUTER ASSISTANT                        3.0
#                SPRINKLER FITTER FIRE PROTECTION SPECI    3.0
#                ADMINISTRATION/INSTRUCTOR                 3.0
#                LEAD UI/UX DEVELOPER                      3.0
#                POLICY/ LAWYER                            3.0
#                LAN/WAN ANALYST                           3.0
#                SR MGR                                    3.0
# Romney, Mitt   MD - UROLOGIST                            5.0
#                DISTRICT REPRESENTATIVE                   5.0
#                INDEPENDENT PROFESSIONAL                  3.0
#                REMODELER & SEMI RETIRED                  3.0
#                AFFORDABLE REAL ESTATE DEVELOPER          3.0
#                IFC CONTRACTING SOLUTIONS                 3.0
#                3RD GENERATION FAMILY BUSINESS OWNER      3.0
# Name: contb_receipt_amt, dtype: float64

# %%
emp_mapping = {
'INFORMATION REQUESTED PER BEST EFFORTS' : 'NOT PROVIDED',
'INFORMATION REQUESTED' : 'NOT PROVIDED',
'SELF' : 'SELF-EMPLOYED',
'SELF EMPLOYED' : 'SELF-EMPLOYED',
}
# If no mapping provided, return x
f = lambda x: emp_mapping.get(x, x)
fec.contbr_employer = fec.contbr_employer.map(f)
grouped.apply(get_top_amounts, 'contbr_employer', n=10)
# Out:
# cand_nm        contbr_employer
# Obama, Barack  SOLIYA                                3.0
#                CARR ENTERPRISES                      3.0
#                PENN STATE DICKINSON SCHOOL OF LAW    3.0
#                CADUCEUS OCCUPATIONAL MEDICINE        3.0
#                N.A.                                  3.0
#                REAL ENERGY CONSULTING SERVICES       3.0
#                JPDSYSTEMS, LLC                       3.0
#                CASS REGIONAL MED. CENTER             2.5
#                ARCON CORP                            2.0
#                THE VICTORIA GROUP, INC.              2.0
# Romney, Mitt   EASTHAM CAPITAL                       5.0
#                GREGORY GALLIVAN                      5.0
#                DIRECT LENDERS LLC                    5.0
#                LOUGH INVESTMENT ADVISORY LLC         4.0
#                WATERWORKS INDUSRTIES                 3.0
#                WILL MERRIFIELD                       3.0
#                HONOLD COMMUNICTAIONS                 3.0
#                INDEPENDENT PROFESSIONAL              3.0
#                UPTOWN CHEAPSKATE                     3.0
#                UN                                    3.0
# Name: contb_receipt_amt, dtype: float64

# %%
bins = np.array([0, 1, 10, 100, 1000, 10000, 100000, 1000000, 10000000])

# %%
labels = pd.cut(fec_mrbo.contb_receipt_amt, bins)

# %%
labels
# Out:
# 411           (10, 100]
# 412         (100, 1000]
# 413         (100, 1000]
# 414           (10, 100]
# 415           (10, 100]
# 416           (10, 100]
# 417         (100, 1000]
# 418           (10, 100]
# 419         (100, 1000]
# 420           (10, 100]
# 421           (10, 100]
# 422         (100, 1000]
# 423         (100, 1000]
# 424         (100, 1000]
# 425         (100, 1000]
# 426         (100, 1000]
# 427       (1000, 10000]
# 428         (100, 1000]
# 429         (100, 1000]
# 430           (10, 100]
# 431       (1000, 10000]
# 432         (100, 1000]
# 433         (100, 1000]
# 434         (100, 1000]
# 435         (100, 1000]
# 436         (100, 1000]
# 437           (10, 100]
# 438         (100, 1000]
# 439         (100, 1000]
# 440           (10, 100]
#               ...
# 701356        (10, 100]
# 701357          (1, 10]
# 701358        (10, 100]
# 701359        (10, 100]
# 701360        (10, 100]
# 701361        (10, 100]
# 701362      (100, 1000]
# 701363        (10, 100]
# 701364        (10, 100]
# 701365        (10, 100]
# 701366        (10, 100]
# 701367        (10, 100]
# 701368      (100, 1000]
# 701369        (10, 100]
# 701370        (10, 100]
# 701371        (10, 100]
# 701372        (10, 100]
# 701373        (10, 100]
# 701374        (10, 100]
# 701375        (10, 100]
# 701376    (1000, 10000]
# 701377        (10, 100]
# 701378        (10, 100]
# 701379      (100, 1000]
# 701380    (1000, 10000]
# 701381        (10, 100]
# 701382      (100, 1000]
# 701383          (1, 10]
# 701384        (10, 100]
# 701385      (100, 1000]
# Name: contb_receipt_amt, Length: 694282, dtype: category
# Categories (8, interval[int64]): [(0, 1] < (1, 10] < (10, 100] < (100, 1000] < (1000, 10000] < (10000, 100000] < (100000, 1000000] < (1000000, 10000000]]

# %%
grouped = fec_mrbo.groupby(['cand_nm', labels])

# %%
grouped.size().unstack(0)
# Out:
# cand_nm              Obama, Barack  Romney, Mitt
# contb_receipt_amt
# (0, 1]                       493.0          77.0
# (1, 10]                    40070.0        3681.0
# (10, 100]                 372280.0       31853.0
# (100, 1000]               153991.0       43357.0
# (1000, 10000]              22284.0       26186.0
# (10000, 100000]                2.0           1.0
# (100000, 1000000]              3.0           NaN
# (1000000, 10000000]            4.0           NaN

# %%
bucket_sums = grouped.contb_receipt_amt.sum().unstack(0)

# %%
bucket_sums
# Out:
# cand_nm              Obama, Barack  Romney, Mitt
# contb_receipt_amt
# (0, 1]                      318.24         77.00
# (1, 10]                  337267.62      29819.66
# (10, 100]              20288981.41    1987783.76
# (100, 1000]            54798531.46   22363381.69
# (1000, 10000]          51753705.67   63942145.42
# (10000, 100000]           59100.00      12700.00
# (100000, 1000000]       1490683.08           NaN
# (1000000, 10000000]     7148839.76           NaN

# %%
normed_sums = bucket_sums.div(bucket_sums.sum(axis=1), axis=0)

# %%
normed_sums
# Out:
# cand_nm              Obama, Barack  Romney, Mitt
# contb_receipt_amt
# (0, 1]                    0.805182      0.194818
# (1, 10]                   0.918767      0.081233
# (10, 100]                 0.910769      0.089231
# (100, 1000]               0.710176      0.289824
# (1000, 10000]             0.447326      0.552674
# (10000, 100000]           0.823120      0.176880
# (100000, 1000000]         1.000000           NaN
# (1000000, 10000000]       1.000000           NaN

# %%
normed_sums[:-2].plot(kind='barh', stacked=True)

# %%
grouped = fec_mrbo.groupby(['cand_nm', 'contbr_st'])

# %%
totals = grouped.contb_receipt_amt.sum().unstack(0).fillna(0)

# %%
totals = totals[totals.sum(1) > 100000]

# %%
totals[:10]
# Out:
# cand_nm    Obama, Barack  Romney, Mitt
# contbr_st
# AK             281840.15      86204.24
# AL             543123.48     527303.51
# AR             359247.28     105556.00
# AZ            1506476.98    1888436.23
# CA           23824984.24   11237636.60
# CO            2132429.49    1506714.12
# CT            2068291.26    3499475.45
# DC            4373538.80    1025137.50
# DE             336669.14      82712.00
# FL            7318178.58    8338458.81

# %%
percent = totals.div(totals.sum(1), axis=0)

# %%
percent[:10]
# Out:
# cand_nm    Obama, Barack  Romney, Mitt
# contbr_st
# AK              0.765778      0.234222
# AL              0.507390      0.492610
# AR              0.772902      0.227098
# AZ              0.443745      0.556255
# CA              0.679498      0.320502
# CO              0.585970      0.414030
# CT              0.371476      0.628524
# DC              0.810113      0.189887
# DE              0.802776      0.197224
# FL              0.467417      0.532583

# %%
from mpl_toolkits.basemap import Basemap, cm
import numpy as np
from matplotlib import rcParams
from matplotlib.collections import LineCollection
import matplotlib.pyplot as plt
from shapelib import ShapeFile
import dbflib
obama = percent['Obama, Barack']
fig = plt.figure(figsize=(12, 12))
ax = fig.add_axes([0.1,0.1,0.8,0.8])
lllat = 21; urlat = 53; lllon = -118; urlon = -62
m = Basemap(ax=ax, projection='stere',
lon_0=(urlon + lllon) / 2, lat_0=(urlat + lllat) / 2,
llcrnrlat=lllat, urcrnrlat=urlat, llcrnrlon=lllon,
urcrnrlon=urlon, resolution='l')
m.drawcoastlines()
m.drawcountries()
shp = ShapeFile('../states/statesp020')
dbf = dbflib.open('../states/statesp020')
for npoly in range(shp.info()[0]):
# Draw colored polygons on the map
    shpsegs = []
    shp_object = shp.read_object(npoly)
    verts = shp_object.vertices()
    rings = len(verts)
    for ring in range(rings):
        lons, lats = zip(*verts[ring])
        x, y = m(lons, lats)
        shpsegs.append(zip(x,y))
        if ring == 0:
            shapedict = dbf.read_record(npoly)
        name = shapedict['STATE']
    lines = LineCollection(shpsegs,antialiaseds=(1,))
# state_to_code dict, e.g. 'ALASKA' -> 'AK', omitted
    try:
        per = obama[state_to_code[name.upper()]]
    except KeyError:
        continue
    lines.set_facecolors('k')
    lines.set_alpha(0.75 * per) # Shrink the percentage a bit
    lines.set_edgecolors('k')
    lines.set_linewidth(0.3)
    ax.add_collection(lines)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-411-75a4030ba3b5> in <module>
# ----> 1 from mpl_toolkits.basemap import Basemap, cm
#       2 import numpy as np
#       3 from matplotlib import rcParams
#       4 from matplotlib.collections import LineCollection
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'mpl_toolkits.basemap'
